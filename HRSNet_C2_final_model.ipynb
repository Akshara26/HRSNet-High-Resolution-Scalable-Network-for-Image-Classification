# %%
# !pip install timm
import torch
import torch.nn as nn
import torchsummary as summary
import numpy as np
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torchvision.models as models
from torch.utils.data import DataLoader, random_split
# import timm

# %%
import torchvision

# %%
class Stem(nn.Module): # Reduce size to 1/4 of initial
    def __init__(self):
        super(Stem, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=2,padding=1)
        self.batchNorm1 = nn.BatchNorm2d(64)
        self.reLU1= nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3,stride=2,padding=1)
        self.batchNorm2= nn.BatchNorm2d(64)
        self.reLU2 = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv1(x)
        x = self.batchNorm1(x)
        x = self.reLU1(x)
        x = self.conv2(x)
        x = self.batchNorm2(x)
        x = self.reLU2(x)
        return x

class Bottleneck(nn.Module):
    def __init__(self,in_channels,out_channels=256):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 64, kernel_size=1)
        self.batchNorm1 = nn.BatchNorm2d(64)
        self.relu1 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3,stride=1, padding=1)
        self.batchNorm2 = nn.BatchNorm2d(64)
        self.relu2=nn.ReLU(inplace=True)
        self.conv3 = nn.Conv2d(64, out_channels, kernel_size=1)
        self.batchNorm3 = nn.BatchNorm2d(out_channels)
        self.downsample=nn.Sequential()

        self.downsample = nn.Sequential()
        if in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1),
                nn.BatchNorm2d(out_channels)
            )
        self.relu3=nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x
        x = self.conv1(x)
        x = self.batchNorm1(x)
        x=self.relu1(x)
        x = self.conv2(x)
        x = self.batchNorm2(x)
        x=self.relu2(x)
        x = self.conv3(x)
        x = self.batchNorm3(x)

        identity = self.downsample(identity)
        x += identity
        x=self.relu3(x)

        return x

class Stage1(nn.Module):
    def __init__(self):
        super(Stage1, self).__init__()
        self.unit1=Bottleneck(64,256)
        self.unit2=Bottleneck(256,256)
        self.unit3=Bottleneck(256,256)
        self.unit4=Bottleneck(256,256)

    def forward(self, x):
        x=self.unit1(x)
        x=self.unit2(x)
        x=self.unit3(x)
        x=self.unit4(x)
        return x

class Trans1(nn.Module):
    def __init__(self,c):
        super(Trans1, self).__init__()
        self.layer1=nn.Sequential(
            nn.Conv2d(256,c,kernel_size=3,padding=1),
            nn.BatchNorm2d(c),
            nn.ReLU(inplace=True)
        )

        self.layer2=nn.Sequential(
            nn.Conv2d(256,2*c,kernel_size=3,stride=2,padding=1),
            nn.BatchNorm2d(2*c),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        out = [self.layer1(x), self.layer2(x)]
        return out

class ResUnit(nn.Module): # Pre-activation Residual Unit
    def __init__(self,in_channels,out_channels):
        super(ResUnit, self).__init__()
        self.bn1=nn.BatchNorm2d(out_channels)
        self.relu1=nn.ReLU(inplace=True)
        self.conv1=nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn2=nn.BatchNorm2d(out_channels)
        self.relu2=nn.ReLU(inplace=True)
        self.conv2=nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)

        self.downsample=nn.Sequential()
        if in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        identity=x
        x=self.bn1(x)
        x=self.relu1(x)
        x=self.conv1(x)
        x=self.bn2(x)
        x=self.relu2(x)
        x=self.conv2(x)


        identity=self.downsample(identity)
        x+=identity
        return x

class M_Block(nn.Module): # Modularised Block
    def __init__(self,c,stage,trans):
        super(M_Block, self).__init__()
        self.branches=nn.ModuleList()
        if trans==True:
            self.trans=1
        else:
            self.trans=0
        for i in range(stage):
            self.branches.append(nn.Sequential(
                ResUnit(c*(2**i),c*(2**i)),
                ResUnit(c*(2**i),c*(2**i)),
                ResUnit(c*(2**i),c*(2**i)),
                ResUnit(c*(2**i),c*(2**i))
            ))

        self.fusion=nn.ModuleList()
        for i in range(stage+self.trans):
            branch=nn.ModuleList()
            for j in range(stage):
                if i==j:
                    branch.append(nn.Sequential())
                elif i<j:
                    branch.append(nn.Sequential(
                        nn.Conv2d(c*(2**j),c*(2**i),kernel_size=1),
                        nn.BatchNorm2d(c*(2**i)),
                        nn.Upsample(scale_factor=2**(j-i), mode='nearest')
                    ))
                else:
                    downsample=[]
                    for k in range(i-j):
                        downsample.append(nn.Sequential(
                            nn.Conv2d(c*(2**(j+k)),c*(2**(j+k+1)),kernel_size=3,stride=2,padding=1),
                            nn.BatchNorm2d(c*(2**(j+k+1)))
                        ))
                    downsample.append(nn.ReLU(inplace=True))

                    branch.append(nn.Sequential(*downsample))
            self.fusion.append(branch)



    def forward(self, x):
        out=[]

        for i in range(len(self.branches)):
            out.append(self.branches[i](x[i]))

        out_fusion=[]

        for i in range(len(self.fusion)):
            temp=[]
            for j in range(len(self.fusion[i])):
                temp.append(self.fusion[i][j](out[j]))

            out_fusion.append(sum(temp))

        for i in range(len(out_fusion)):
            out_fusion[i]=nn.ReLU(inplace=True)(out_fusion[i])
        return out_fusion


class Stage2(nn.Module):
    def __init__(self, c):
        super(Stage2, self).__init__()
        self.m_block1 = M_Block(c,stage=2,trans=False)
        self.m_block2 = M_Block(c,stage=2,trans=False)
        self.m_block3 = M_Block(c,stage=2,trans=False)
        self.m_block4 = M_Block(c,stage=2,trans=True)

    def forward(self, x):
        residual=x
        x=self.m_block1(x)
        x=self.m_block2(x)
        x=self.m_block3(x)
        x=x+residual
        x=self.m_block4(x)
        return x

class Stage3(nn.Module):
    def __init__(self, c):
        super(Stage3, self).__init__()
        self.m_block1 = M_Block(c,stage=3,trans=False)
        self.m_block2 = M_Block(c,stage=3,trans=False)
        self.m_block3 = M_Block(c,stage=3,trans=False)
        self.m_block4 = M_Block(c,stage=3,trans=True)

    def forward(self, x):
        residual=x
        x=self.m_block1(x)
        x=self.m_block2(x)
        x=self.m_block3(x)
        x=x+residual
        x=self.m_block4(x)
        return x

class Stage4(nn.Module):
    def __init__(self, c):
        super(Stage4, self).__init__()
        self.m_block1 = M_Block(c,stage=4,trans=False)
        self.m_block2 = M_Block(c,stage=4,trans=False)
        self.m_block3 = M_Block(c,stage=4,trans=False)
        self.m_block4 = M_Block(c,stage=4,trans=False)

    def forward(self, x):
        residual=x
        x=self.m_block1(x)
        x=self.m_block2(x)
        x=self.m_block3(x)
        x=x+residual
        x=self.m_block4(x)

        return x


class seghead(nn.Module):
    def __init__(self,c):
        super(seghead, self).__init__()
        self.branches=nn.ModuleList()
        for i in range(4):
            self.branches.append(nn.Sequential(
                nn.Upsample(scale_factor=2**(i), mode='nearest'),
                        nn.Conv2d(c*(2**i),c*(2**i),kernel_size=1),
                        nn.BatchNorm2d(c*(2**i))
            ))

        # Produce 21 feature maps for each class
        self.final=nn.Sequential(
            nn.Conv2d(15*c,15*c,kernel_size=1),
            nn.BatchNorm2d(15*c),
            nn.ReLU(inplace=True),
            nn.Conv2d(15*c,21,kernel_size=1)
        )


    def forward(self, x):
        out=[]
        for i in range(len(self.branches)):
            out.append(self.branches[i](x[i]))

        out=torch.cat(out,dim=1)
        out=self.final(out)
        return out

class Head(nn.Module):
    def __init__(self,c):
        super(Head, self).__init__()
        self.branches=nn.ModuleList()
        for i in range(4):
            self.branches.append(nn.Sequential(
                nn.Conv2d((2**i)*c,(2**i)*32,kernel_size=1,stride=1),
                nn.BatchNorm2d((2**i)*32),
                nn.ReLU(inplace=True),
                nn.Conv2d((2**i)*32,(2**i)*32,kernel_size=3,stride=1,padding=1),
                nn.BatchNorm2d((2**i)*32),
                nn.ReLU(inplace=True),
                nn.Conv2d((2**i)*32,(2**i)*128,kernel_size=1,stride=1),
                nn.BatchNorm2d((2**i)*128),
                nn.ReLU(inplace=True)
            ))

        self.downsamples=nn.ModuleList()
        for i in range(4):
            self.downsamples.append(nn.Sequential(
                nn.Conv2d((2**i)*c,(2**i)*128,kernel_size=1,stride=1),
                nn.BatchNorm2d((2**i)*128),

            ))

        self.merges=nn.ModuleList()
        for i in range(3):
            self.merges.append(nn.Sequential(
                nn.Conv2d((2**i)*128,(2**i)*256,kernel_size=3,stride=2,padding=1),
                nn.BatchNorm2d((2**i)*256),
                nn.ReLU(inplace=True)
            ))

        self.final=nn.Sequential(
            nn.Conv2d(1024,2048,kernel_size=1,stride=1),
            nn.BatchNorm2d(2048),
            nn.ReLU(inplace=True)
        )

        self.fc=nn.Linear(2048,100)


    def forward(self, x):
        out=[]

        for i in range(len(self.branches)):
            # print(x[i].size())
            # print(self.branches[i](x[i]).size(),self.downsamples[i](x[i]).size())
            out.append(self.branches[i](x[i])+self.downsamples[i](x[i]))
        y=self.merges[0](out[0])
        # print("out1",out[1].size(),y.size())
        y=self.merges[1](out[1]+y)
        # print("out2",out[2].size(),y.size())
        y=self.merges[2](out[2]+y)
        # print("out3",out[3].size(),y.size())
        y=self.final(out[3]+y)
        y=nn.AvgPool2d(kernel_size=y.size()[2:])(y)
        y_flattened = y.view(y.size(0), -1)
        preds=self.fc(y_flattened)

        return preds


class HRNet(nn.Module):
    def __init__(self, c=30):
        super(HRNet, self).__init__()
        self.stem = Stem()
        self.stage1 = Stage1()
        self.trans1= Trans1(c)
        self.stage2=Stage2(c)
        self.stage3=Stage3(c)
        self.stage4=Stage4(c)
        self.head=Head(c)
        # self.seghead=seghead(c)


    def forward(self, x):
        x = self.stem(x)
        x=self.stage1(x)
        x= self.trans1(x)
        x=self.stage2(x)
        x=self.stage3(x)
        x=self.stage4(x)
        x=self.head(x)
        return x


class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.best_score = None
        self.early_stop = False
        self.counter = 0

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print("Device",device)
# model = HRNet(c=30).to(device)

# model = timm.create_model('hrnet_w30', pretrained=False, num_classes=100).to(device)
# print(model)

# %%
mymodel=HRNet(c=2).to(device)
# print(mymodel)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Download and load the CIFAR100 dataset
trainset = datasets.CIFAR100(root='./data', train=True,
                             download=True, transform=transform)

# Split the trainset into train and validation sets
num_train = len(trainset)
indices = list(range(num_train))
split = int(0.8 * num_train)  # 80% for training

train_subset, val_subset = random_split(trainset, [split, num_train - split])

trainloader = DataLoader(train_subset, batch_size=16, shuffle=True, num_workers=2)
valloader = DataLoader(val_subset, batch_size=16, shuffle=False, num_workers=2)

# Load the test dataset
testset = datasets.CIFAR100(root='./data', train=False,
                            download=True, transform=transform)
testloader = DataLoader(testset, batch_size=16, shuffle=False, num_workers=2)

# Get the list of classes
classes = trainset.classes

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(mymodel.parameters(), lr=0.005, momentum=0.9)

print("Data loaders prepared: Train, Validation, and Test")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def save_checkpoint(epoch, model, optimizer, filename):
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }
    torch.save(checkpoint, filename)

# %%
def load_checkpoint(filename, model, optimizer, device):
    # Load the checkpoint file
    checkpoint = torch.load(filename, map_location=device)

    # Restore the model and optimizer state
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    # Return the epoch number if needed
    return checkpoint['epoch']

# %%
early_stopping = EarlyStopping(patience=3, verbose=True)

# Track loss for plotting
train_losses = []
val_losses = []

for epoch in range(25):  # limited epoch count for demonstration
    running_loss = 0.0
    total_samples = 0  # To count the total number of samples processed
    mymodel.train()  # Ensure the model is in training mode
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = mymodel(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        total_samples += inputs.size(0)
        if i % 1000 == 999:  # Print every 500 mini-batches
            current_loss = running_loss / total_samples  # Calculate current average loss
            print('[%d, %5d] loss: %.3f' % (epoch + 1, i + 1, current_loss))
            running_loss = 0.0
            total_samples = 0  # Reset counters

    # Calculate average training loss
    if total_samples > 0:  # Check to prevent division by zero
        train_loss = running_loss / total_samples
        train_losses.append(train_loss)

    # Validation phase
    mymodel.eval()
    val_running_loss = 0.0
    val_total_samples = 0
    with torch.no_grad():
        for data in valloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = mymodel(inputs)
            loss = criterion(outputs, labels)
            val_running_loss += loss.item() * inputs.size(0)
            val_total_samples += inputs.size(0)



    save_checkpoint(epoch, mymodel, optimizer, '/content/drive/MyDrive/Colab Notebooks/checkpoint_HrsNet_c2_early_stop1.pth')
    print('Saved checkpoint with epoch: ' , epoch)


    if val_total_samples > 0:
        val_loss = val_running_loss / val_total_samples
        val_losses.append(val_loss)

    print(f'Epoch {epoch + 1} - Training Loss: {train_loss:.3f}, Validation Loss: {val_loss:.3f}')

    # Early stopping based on validation loss
    early_stopping(val_loss, mymodel)
    if early_stopping.early_stop:
        print("Early stopping triggered")
        break
print('Finished Training')
# Out:
# [1,  1000] loss: 4.391
# [1,  2000] loss: 4.052
# Saved checkpoint with epoch:  0
# Epoch 1 - Training Loss: 3.923, Validation Loss: 3.885
# [2,  1000] loss: 3.765
# [2,  2000] loss: 3.570
# Saved checkpoint with epoch:  1
# Epoch 2 - Training Loss: 3.444, Validation Loss: 3.525
# [3,  1000] loss: 3.302
# [3,  2000] loss: 3.151
# Saved checkpoint with epoch:  2
# Epoch 3 - Training Loss: 3.045, Validation Loss: 3.040
# [4,  1000] loss: 2.930
# [4,  2000] loss: 2.829
# Saved checkpoint with epoch:  3
# Epoch 4 - Training Loss: 2.762, Validation Loss: 2.638
# [5,  1000] loss: 2.622
# [5,  2000] loss: 2.585
# Saved checkpoint with epoch:  4
# Epoch 5 - Training Loss: 2.537, Validation Loss: 2.710
# EarlyStopping counter: 1 out of 3
# [6,  1000] loss: 2.403
# [6,  2000] loss: 2.359
# Saved checkpoint with epoch:  5
# Epoch 6 - Training Loss: 2.321, Validation Loss: 2.571
# [7,  1000] loss: 2.187
# [7,  2000] loss: 2.171
# Saved checkpoint with epoch:  6
# Epoch 7 - Training Loss: 2.162, Validation Loss: 2.451
# [8,  1000] loss: 2.027
# [8,  2000] loss: 2.024
# Saved checkpoint with epoch:  7
# Epoch 8 - Training Loss: 2.001, Validation Loss: 2.365
# [9,  1000] loss: 1.891
# [9,  2000] loss: 1.895
# Saved checkpoint with epoch:  8
# Epoch 9 - Training Loss: 1.870, Validation Loss: 1.933
# [10,  1000] loss: 1.723
# [10,  2000] loss: 1.759
# Saved checkpoint with epoch:  9
# Epoch 10 - Training Loss: 1.721, Validation Loss: 1.943
# EarlyStopping counter: 1 out of 3
# [11,  1000] loss: 1.594
# [11,  2000] loss: 1.629
# Saved checkpoint with epoch:  10
# Epoch 11 - Training Loss: 1.623, Validation Loss: 1.844
# [12,  1000] loss: 1.446
# [12,  2000] loss: 1.533
# Saved checkpoint with epoch:  11
# Epoch 12 - Training Loss: 1.513, Validation Loss: 1.884
# EarlyStopping counter: 1 out of 3
# [13,  1000] loss: 1.327
# [13,  2000] loss: 1.414
# Saved checkpoint with epoch:  12
# Epoch 13 - Training Loss: 1.423, Validation Loss: 1.901
# EarlyStopping counter: 2 out of 3
# [14,  1000] loss: 1.237
# [14,  2000] loss: 1.282
# Saved checkpoint with epoch:  13
# Epoch 14 - Training Loss: 1.340, Validation Loss: 1.787
# [15,  1000] loss: 1.093
# [15,  2000] loss: 1.199
# Saved checkpoint with epoch:  14
# Epoch 15 - Training Loss: 1.217, Validation Loss: 1.836
# EarlyStopping counter: 1 out of 3
# [16,  1000] loss: 0.988
# [16,  2000] loss: 1.075
# Saved checkpoint with epoch:  15
# Epoch 16 - Training Loss: 1.128, Validation Loss: 1.890
# EarlyStopping counter: 2 out of 3
# [17,  1000] loss: 0.876
# [17,  2000] loss: 0.973
# Saved checkpoint with epoch:  16
# Epoch 17 - Training Loss: 1.000, Validation Loss: 1.915
# EarlyStopping counter: 3 out of 3
# Early stopping triggered
# Finished Training

# %%
#save_checkpoint(5, mymodel, optimizer, '/content/drive/MyDrive/Colab Notebooks/checkpoint_HrsNet_c2_early_stop1.pth')
print('Finished Training')

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = mymodel(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 50 %

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = mymodel(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Training & Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Assuming HRNet and device are defined, and your model has been initialized
# You may need to redefine your model architecture if it's not available in the scopedevice = 'cuda' if torch.cuda.is_available() else 'cpu'
mymodel = HRNet(c=2).to(device)
optimizer = optim.SGD(mymodel.parameters(), lr=0.005, momentum=0.9)

# Load the checkpoint; specify the path to your checkpoint file
last_epoch = load_checkpoint('/content/drive/MyDrive/Colab Notebooks/checkpoint_HrsNet_c2_early_stop1.pth', mymodel, optimizer, device)
# Resume training

# %%
import torch

correct = 0
total = 0
class_correct = dict()
class_total = dict()

# Using numbers from 1 to 100 as class identifiers
class_names = list(range(1, 101))  # This creates a list from 1 to 100

with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = mymodel(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for i in range(len(labels)):
            label = labels[i]
            correct_pred = (predicted[i] == label).item()
            if label.item() not in class_correct:
                class_correct[label.item()] = 0
                class_total[label.item()] = 0
            class_correct[label.item()] += correct_pred
            class_total[label.item()] += 1

# Calculating overall accuracy
overall_accuracy = 100 * correct / total
print('Accuracy of the network on the 10000 test images: %d %%' % overall_accuracy)

# Calculating accuracy for each class
class_accuracies = {}
for class_idx in range(1, 101):
    if class_idx in class_total:
        accuracy = 100.0 * class_correct[class_idx] / class_total[class_idx]
        class_accuracies[class_idx] = accuracy
        print('Accuracy of class %d: %2d %%' % (class_idx, accuracy))

# Printing top 5 categories by accuracy
top_5 = sorted(class_accuracies.items(), key=lambda x: x[1], reverse=True)[:5]
print("\nTop 5 categories with highest accuracy:")
for class_idx, accuracy in top_5:
    print(f"Class {class_idx}: {accuracy:.2f}%")
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Accuracy of the network on the 10000 test images: 50 %
# Accuracy of class1 : 61 %
# Accuracy of class2 : 66 %
# Accuracy of class3 : 51 %
# Accuracy of Ellipsis : 21 %
# Accuracy of classN : 27 %
#
# Top 5 categories with highest accuracy:
# class2: 66.00%
# class1: 61.00%
# class3: 51.00%
# classN: 27.00%
# Ellipsis: 21.00%

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

correct = 0
total = 0
class_correct = dict()
class_total = dict()
image_samples = {}

with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = mymodel(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for i in range(len(labels)):
            label = labels[i]
            pred = predicted[i]
            correct_pred = (pred == label).item()
            if label.item() not in class_correct:
                class_correct[label.item()] = 0
                class_total[label.item()] = 0
                image_samples[label.item()] = []
            class_correct[label.item()] += correct_pred
            class_total[label.item()] += 1

            # Store up to 3 images for each class for visualization
            if len(image_samples[label.item()]) < 3:
                image_samples[label.item()].append((images[i].cpu(), label.item(), pred.item()))

# Displaying images from the top classes
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Calculating and sorting accuracies
class_accuracies = {}
for class_idx in range(1, 101):
    if class_idx in class_total:
        accuracy = 100.0 * class_correct[class_idx] / class_total[class_idx]
        class_accuracies[class_idx] = accuracy

top_5_classes = sorted(class_accuracies.items(), key=lambda x: x[1], reverse=True)[:5]
top_5_indices = [x[0] for x in top_5_classes]

# Visualizing images from the top 5 classes
for class_idx in top_5_indices:
    print(f"Class {class_idx} Samples:")
    for image, true_label, pred_label in image_samples[class_idx]:
        print(f"Actual Label: {true_label}, Predicted Label: {pred_label}")
        imshow(img=torchvision.utils.make_grid(image))
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Class 94 Samples:
# Actual Label: 94, Predicted Label: 94
# Actual Label: 94, Predicted Label: 94
# Actual Label: 94, Predicted Label: 94
# Class 82 Samples:
# Actual Label: 82, Predicted Label: 83
# Actual Label: 82, Predicted Label: 82
# Actual Label: 82, Predicted Label: 82
# Class 60 Samples:
# Actual Label: 60, Predicted Label: 60
# Actual Label: 60, Predicted Label: 60
# Actual Label: 60, Predicted Label: 60
# Class 52 Samples:
# Actual Label: 52, Predicted Label: 52
# Actual Label: 52, Predicted Label: 52
# Actual Label: 52, Predicted Label: 52
# Class 48 Samples:
# Actual Label: 48, Predicted Label: 26
# Actual Label: 48, Predicted Label: 48
# Actual Label: 48, Predicted Label: 48

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torchvision

correct = 0
total = 0
class_correct = dict()
class_total = dict()
image_samples = {}

with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = mymodel(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for i in range(len(labels)):
            label = labels[i]
            pred = predicted[i]
            correct_pred = (pred == label).item()
            if label.item() not in class_correct:
                class_correct[label.item()] = 0
                class_total[label.item()] = 0
                image_samples[label.item()] = []
            class_correct[label.item()] += correct_pred
            class_total[label.item()] += 1

            # Store up to 3 images for each class for visualization
            if len(image_samples[label.item()]) < 3:
                image_samples[label.item()].append((images[i].cpu(), label.item(), pred.item()))

# Displaying images from the top classes
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Calculating and sorting accuracies
class_accuracies = {}
for class_idx in range(1, 101):
    if class_idx in class_total:
        accuracy = 100.0 * class_correct[class_idx] / class_total[class_idx]
        class_accuracies[class_idx] = accuracy

top_5_classes = sorted(class_accuracies.items(), key=lambda x: x[1], reverse=True)[:5]
top_5_indices = [x[0] for x in top_5_classes]

# Visualizing images from the top 5 classes
for class_idx in top_5_indices:
    print(f"Class {class_idx} Samples:")
    for image, true_label, pred_label in image_samples[class_idx]:
        print(f"Actual Label: {true_label}, Predicted Label: {pred_label}")
        imshow(torchvision.utils.make_grid(image))

# %%
save_checkpoint(epoch, mymodel, optimizer, 'checkpoint_c2_early_stop2.pth')

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = mymodel(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 60 %
